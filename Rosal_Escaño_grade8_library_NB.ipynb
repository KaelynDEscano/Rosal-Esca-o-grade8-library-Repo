# %% [markdown]
# <a href="https://colab.research.google.com/github/KaelynDEscano/Rosal-Esca-o-grade8-library-Repo/blob/main/Rosal_Esca%C3%B1o_grade8_library_NB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
url = "https://raw.githubusercontent.com/KaelynDEscano/Rosal-Esca-o-grade8-library-Repo/refs/heads/main/books.json.txt"
response = requests.get(url)
books_data = response.json()

total_library_books = 0
print("--- Library Book Details ---")
for book in books_data['books']:
    title = book.get('title', 'N/A')
    available_copies = book.get('details', {}).get('available', 0)
    total_copies = book.get('details', {}).get('copies', 0)

    print(f"Title: {title}")
    print(f"Available: {available_copies}")
    total_library_books += total_copies
print("----------------------------")
print(f"Total number of books in the library: {total_library_books}")
# Out:
# --- Library Book Details ---
# Title: Introduction to Python
# Available: 3
# Title: Data Structures Basics
# Available: 2
# Title: Web Development Essentials
# Available: 6
# ----------------------------
# Total number of books in the library: 15

# %%
# !pip install firebase-admin

# %%
import firebase_admin
from firebase_admin import credentials, db

# Check if the default Firebase app is already initialized
if not firebase_admin._apps: # _apps is a dictionary containing initialized apps
    #Load the private key
    cred = credentials.Certificate("/content/firebase_key.json")
    #Initialize the app with your database URL
    firebase_admin.initialize_app (cred, { "databaseURL": "https://rosal-escano-grade8-library-db-default-rtdb.asia-southeast1.firebasedatabase.app/"})
    print("Firebase connected successfully!")
else:
    print("Firebase app already initialized.")
# Out:
# Firebase app already initialized.

# %%
import json
with open("/content/books.json", "r") as file:
 data = json.load(file)
print("JSON file loaded")
ref = db.reference("books")
for books in data["books"]:
 ref.child(str(books["id"])).set(books)
print("Data uploaded successfully!")
# Out:
# JSON file loaded
# Data uploaded successfully!

# %%
books_ref = db.reference("books")
books_data = books_ref.get()
print(books_data)
# Out:
# {'2001': {'author': 'Juan Dela Cruz', 'details': {'available': 3, 'copies': 5}, 'id': 2001, 'title': 'Introduction to Python'}, '2002': {'author': 'Maria Santos', 'details': {'available': 2, 'copies': 4}, 'id': 2002, 'title': 'Data Structures Basics'}, '2003': {'author': 'Carlos Reyes', 'details': {'available': 6, 'copies': 6}, 'id': 2003, 'title': 'Web Development Essentials'}}

# %%
for books_id, info in books_data.items():
 print(info["title"])
# Out:
# Introduction to Python
# Data Structures Basics
# Web Development Essentials

# %%
total = 0
for book in data["books"]:
  print(f"Title: {book['title']}")
  print(f"Available: {book['details']['available']}")
  total += book['details']['copies']
print("Total number of books: " , total)
# Out:
# Title: Introduction to Python
# Available: 3
# Title: Data Structures Basics
# Available: 2
# Title: Web Development Essentials
# Available: 6
# Total number of books:  15
